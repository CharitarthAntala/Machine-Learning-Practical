# %% [markdown]
# <a href="https://colab.research.google.com/github/CharitarthAntala/Machine-Learning-Practical/blob/main/Pandas_method3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv('/content/auto-mpg.csv')
print(df.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df.head()
#df.tail()
print(df['horsepower'].to_string())
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
# 5      198
# 6      220
# 7      215
# 8      225
# 9      190
# 10     170
# 11     160
# 12     150
# 13     225
# 14      95
# 15      95
# 16      97
# 17      85
# 18      88
# 19      46
# 20      87
# 21      90
# 22      95
# 23     113
# 24      90
# 25     215
# 26     200
# 27     210
# 28     193
# 29      88
# 30      90
# 31      95
# 32       ?
# 33     100
# 34     105
# 35     100
# 36      88
# 37     100
# 38     165
# 39     175
# 40     153
# 41     150
# 42     180
# 43     170
# 44     175
# 45     110
# 46      72
# 47     100
# 48      88
# 49      86
# 50      90
# 51      70
# 52      76
# 53      65
# 54      69
# 55      60
# 56      70
# 57      95
# 58      80
# 59      54
# 60      90
# 61      86
# 62     165
# 63     175
# 64     150
# 65     153
# 66     150
# 67     208
# 68     155
# 69     160
# 70     190
# 71      97
# 72     150
# 73     130
# 74     140
# 75     150
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  ...  model year      origin
# count  398.000000  398.000000  ...  398.000000  398.000000
# mean    23.514573    5.454774  ...   76.010050    1.572864
# std      7.815984    1.701004  ...    3.697627    0.802055
# min      9.000000    3.000000  ...   70.000000    1.000000
# 25%     17.500000    4.000000  ...   73.000000    1.000000
# 50%     23.000000    4.000000  ...   76.000000    1.000000
# 75%     29.000000    8.000000  ...   79.000000    2.000000
# max     46.600000    8.000000  ...   82.000000    3.000000
#
# [8 rows x 7 columns]

# %%
df['car name'].describe()
# Out:
# count            398
# unique           305
# top       ford pinto
# freq               6
# Name: car name, dtype: object

# %%
print(df[:].mean(),df[:].median())

#variance btw mean & median
print((df[:].mean()-df[:].median())/df[:].median()*100)
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model year        76.010050
# origin             1.572864
# dtype: float64 mpg               23.0
# cylinders          4.0
# displacement     148.5
# weight          2803.5
# acceleration      15.5
# model year        76.0
# origin             1.0
# dtype: float64
# mpg              2.237273
# cylinders       36.369347
# displacement    30.253117
# weight           5.954151
# acceleration     0.439293
# model year       0.013224
# origin          57.286432
# dtype: float64

# %%
#boxplot
#print(plt.boxplot(df['displacement']))
#print(plt.boxplot(df['acceleration']))

for name in df.columns:
  try:
    print(name)
    #plt.boxplot(df[name])
    sn.boxplot(df[name])
    #sn.histplot(df[name])
    plt.show()
  except:
    print('---------')

# %%
for name in df.columns:
  try:
    print(name)
    #plt.boxplot(df[name])
    #sn.boxplot(df[name])
    sn.histplot(df[name])
    plt.show()
  except:
    print('---------')
# Out:
# mpg
# cylinders
# displacement
# horsepower
# weight
# acceleration
# model year
# origin
# car name

# %%
#sn.scatterplot(df['displacement'],df['mpg'])
for name in df.columns:
  try:
    print(name)
    #plt.boxplot(df[name])
    #sn.boxplot(df[name])
    #sn.histplot(df[name])
    sn.scatterplot(df[name],df['mpg'])
    plt.show()
  except:
    print('---------')
# Out:
# mpg
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# cylinders
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# displacement
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
sn.pairplot(df)

# %%
#print(df[df['horsepower']=='?'])
df.loc[df['horsepower']=='?']
#type(df['horsepower'].values)
#np.char.isnumeric(df['columnname'].values)
# Out:
#       mpg  cylinders  displacement  ... model year  origin              car name
# 32   25.0          4          98.0  ...         71       1            ford pinto
# 126  21.0          6         200.0  ...         74       1         ford maverick
# 330  40.9          4          85.0  ...         80       2  renault lecar deluxe
# 336  23.6          4         140.0  ...         80       1    ford mustang cobra
# 354  34.5          4         100.0  ...         81       2           renault 18i
# 374  23.0          4         151.0  ...         82       1        amc concord dl
#
# [6 rows x 9 columns]

# %%
#df['car name'].describe()
#df['car name'].value_counts()
#df.groupby(['car name']).size()
#print(df['car name'].value_counts().to_string())
print(df['origin'].value_counts().to_string())
# Out:
# 1    249
# 3     79
# 2     70

# %%
print(df['cylinders'].value_counts()/df['cylinders'].count())
# Out:
# 4    0.512563
# 8    0.258794
# 6    0.211055
# 3    0.010050
# 5    0.007538
# Name: cylinders, dtype: float64

# %%
pd.crosstab(df['cylinders'],df['origin'])
# Out:
# origin       1   2   3
# cylinders
# 3            0   0   4
# 4           72  63  69
# 5            0   3   0
# 6           74   4   6
# 8          103   0   0
